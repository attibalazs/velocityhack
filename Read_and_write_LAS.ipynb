# %% [markdown]
# # Reading and writing LAS files
#
# This notebook goes with [the Agile blog post](https://agilescientific.com/blog/2017/10/23/x-lines-of-python-load-curves-from-las) of 23 October 2017.
#
# You'll need `welly` in your environment:
#
#     pip install welly
#
# This will also install the latest versions of `striplog` and `lasio`.

# %%
ls ../data/*.LAS
# Out:
# ../data/P-129.LAS  ../data/P-129_out.LAS

# %% [markdown]
# ## Load the LAS file with `lasio`

# %%
import lasio

l = lasio.read('../data/P-129.LAS')

# %% [markdown]
# That's it! But the object itself doesn't tell us much — it's really just a container:

# %%
l.header
# Out:
# {'Version': [HeaderItem(mnemonic=VERS, unit=, value=2.0, descr=),
#   HeaderItem(mnemonic=WRAP, unit=, value=YES, descr=)],
#  'Well': [HeaderItem(mnemonic=STRT, unit=M, value=1.0668, descr=START DEPTH),
#   HeaderItem(mnemonic=STOP, unit=M, value=1939.1376, descr=STOP DEPTH),
#   HeaderItem(mnemonic=STEP, unit=M, value=0.1524, descr=STEP),
#   HeaderItem(mnemonic=NULL, unit=, value=-999.25, descr=NULL VALUE),
#   HeaderItem(mnemonic=COMP, unit=, value=Elmworth Energy Corporation, descr=CO...),
#   HeaderItem(mnemonic=WELL, unit=, value=Kennetcook #2, descr=WELL),
#   HeaderItem(mnemonic=FLD, unit=, value=Windsor Block, descr=FIELD),
#   HeaderItem(mnemonic=LOC, unit=, value=Lat = 45* 12' 34.237" N, descr=LOCATION),
#   HeaderItem(mnemonic=PROV, unit=, value=Nova Scotia, descr=PROVINCE),
#   HeaderItem(mnemonic=UWI, unit=, value=Long = 63* 45'24.460  W, descr=UNIQUE ...),
#   HeaderItem(mnemonic=LIC, unit=, value=P-129, descr=LICENSE NUMBER),
#   HeaderItem(mnemonic=CTRY, unit=, value=CA, descr=COUNTRY (WWW code)),
#   HeaderItem(mnemonic=DATE, unit=, value=10-Oct-2007, descr=LOG DATE {DD-MMM-Y...),
#   HeaderItem(mnemonic=SRVC, unit=, value=Schlumberger, descr=SERVICE COMPANY),
#   HeaderItem(mnemonic=LATI, unit=DEG, value=, descr=LATITUDE),
#   HeaderItem(mnemonic=LONG, unit=DEG, value=, descr=LONGITUDE),
#   HeaderItem(mnemonic=GDAT, unit=, value=, descr=GeoDetic Datum),
#   HeaderItem(mnemonic=SECT, unit=, value=45.20 Deg N, descr=Section),
#   HeaderItem(mnemonic=RANG, unit=, value=PD 176, descr=Range),
#   HeaderItem(mnemonic=TOWN, unit=, value=63.75 Deg W, descr=Township)],
#  'Curves': [CurveItem(mnemonic=DEPT, unit=m, value=, descr=DEPTH, original_mnemonic=DEPT, data.shape=(12718,)),
#   CurveItem(mnemonic=CALI, unit=in, value=, descr=Caliper, original_mnemonic=CALI, data.shape=(12718,)),
#   CurveItem(mnemonic=HCAL, unit=in, value=, descr=HRCC Cal. Caliper, original_mnemonic=HCAL, data.shape=(12718,)),
#   CurveItem(mnemonic=PEF, unit=, value=, descr=Photoelectric Factor, original_mnemonic=PEF, data.shape=(12718,)),
#   CurveItem(mnemonic=DT, unit=us/ft, value=, descr=DT, original_mnemonic=DT, data.shape=(12718,)),
#   CurveItem(mnemonic=DTS, unit=us/ft, value=, descr=DTS, original_mnemonic=DTS, data.shape=(12718,)),
#   CurveItem(mnemonic=DPHI_SAN, unit=m3/m3, value=, descr=Density Porosity (matrix Sandstone), original_mnemonic=DPHI_SAN, data.shape=(12718,)),
#   CurveItem(mnemonic=DPHI_LIM, unit=m3/m3, value=, descr=Density Porosity (matrix Limestone), original_mnemonic=DPHI_LIM, data.shape=(12718,)),
#   CurveItem(mnemonic=DPHI_DOL, unit=m3/m3, value=, descr=Density Porosity (matrix Dolomite), original_mnemonic=DPHI_DOL, data.shape=(12718,)),
#   CurveItem(mnemonic=NPHI_SAN, unit=m3/m3, value=, descr=Thermal Neutron Porosity (matrix Sandstone), original_mnemonic=NPHI_SAN, data.shape=(12718,)),
#   CurveItem(mnemonic=NPHI_LIM, unit=m3/m3, value=, descr=Thermal Neutron Porosity (matrix Limestone), original_mnemonic=NPHI_LIM, data.shape=(12718,)),
#   CurveItem(mnemonic=NPHI_DOL, unit=m3/m3, value=, descr=Thermal Neutron Porosity (matrix Dolomite), original_mnemonic=NPHI_DOL, data.shape=(12718,)),
#   CurveItem(mnemonic=RLA5, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 5, original_mnemonic=RLA5, data.shape=(12718,)),
#   CurveItem(mnemonic=RLA3, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 3, original_mnemonic=RLA3, data.shape=(12718,)),
#   CurveItem(mnemonic=RLA4, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 4, original_mnemonic=RLA4, data.shape=(12718,)),
#   CurveItem(mnemonic=RLA1, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 1, original_mnemonic=RLA1, data.shape=(12718,)),
#   CurveItem(mnemonic=RLA2, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 2, original_mnemonic=RLA2, data.shape=(12718,)),
#   CurveItem(mnemonic=RXOZ, unit=ohm.m, value=, descr=MCFL Standard Resolution Invaded Zone Resistivity, original_mnemonic=RXOZ, data.shape=(12718,)),
#   CurveItem(mnemonic=RXO_HRLT, unit=ohm.m, value=, descr=, original_mnemonic=RXO_HRLT, data.shape=(12718,)),
#   CurveItem(mnemonic=RT_HRLT, unit=ohm.m, value=, descr=HRLT Computed True Resistivity, original_mnemonic=RT_HRLT, data.shape=(12718,)),
#   CurveItem(mnemonic=RM_HRLT, unit=ohm.m, value=, descr=HRLT Mud Resistivity, original_mnemonic=RM_HRLT, data.shape=(12718,)),
#   CurveItem(mnemonic=DRHO, unit=g/cm3, value=, descr=HRDD Density Correction, original_mnemonic=DRHO, data.shape=(12718,)),
#   CurveItem(mnemonic=RHOB, unit=g/cm3, value=, descr=Bulk Density, original_mnemonic=RHOB, data.shape=(12718,)),
#   CurveItem(mnemonic=GR, unit=gAPI, value=, descr=Gamma-Ray, original_mnemonic=GR, data.shape=(12718,)),
#   CurveItem(mnemonic=SP, unit=mV, value=, descr=SP, original_mnemonic=SP, data.shape=(12718,))],
#  'Parameter': [HeaderItem(mnemonic=DREF, unit=, value=KELLY BUSHING, descr=Drilling Measure...),
#   HeaderItem(mnemonic=RUN, unit=, value=1, descr=Run Number),
#   HeaderItem(mnemonic=CSGD, unit=M, value=280.0, descr=Casing Bottom of Driller),
#   HeaderItem(mnemonic=CSGL, unit=M, value=280.0, descr=Casing Bottom of Logger),
#   HeaderItem(mnemonic=CSGS, unit=MM, value=244.5, descr=Current Casing Size),
#   HeaderItem(mnemonic=CSGW, unit=KG/M, value=53.57, descr=Casing Weight),
#   HeaderItem(mnemonic=MUDD, unit=K/M3, value=1110.0, descr=Drilling Fluid Density),
#   HeaderItem(mnemonic=FL, unit=C3, value=7.5, descr=DRILLING FLUID LOSS),
#   HeaderItem(mnemonic=PH, unit=, value=10.5, descr=Drilling Fluid PH),
#   HeaderItem(mnemonic=MUD, unit=, value=Gel-Chem, descr=Drilling Fluid Type),
#   HeaderItem(mnemonic=MUDV, unit=S, value=73.0, descr=Drilling Fluid Viscosity),
#   HeaderItem(mnemonic=GL, unit=M, value=90.3, descr=Elevation of Ground Level),
#   HeaderItem(mnemonic=EREF:1, unit=M, value=94.8, descr=Elevation of Kelly Bus...),
#   HeaderItem(mnemonic=ENG, unit=, value=L. Conway / J. Easton, descr=Engineer'...),
#   HeaderItem(mnemonic=EREF:2, unit=, value=KELLY BUSHING, descr=Log Measured From),
#   HeaderItem(mnemonic=BASE, unit=, value=Dartmouth, descr=Logging Unit Location),
#   HeaderItem(mnemonic=FACT, unit=, value=11864196, descr=Service Order Number),
#   HeaderItem(mnemonic=LIC, unit=, value=, descr=API Serial Number),
#   HeaderItem(mnemonic=PROV, unit=, value=Nova Scotia, descr=County or Rig Name),
#   HeaderItem(mnemonic=UNIT, unit=, value=162, descr=Logging Unit Number),
#   HeaderItem(mnemonic=RMCT, unit=DEGC, value=19.4, descr=Mud Cake Sample Tempe...),
#   HeaderItem(mnemonic=RMFT, unit=DEGC, value=16.9, descr=Mud Filtrate Sample T...),
#   HeaderItem(mnemonic=TMAX, unit=DEGC, value=42.0, descr=Maximum Recorded Temp...),
#   HeaderItem(mnemonic=MUDS, unit=, value=Mud Pit, descr=Mud Sample Source),
#   HeaderItem(mnemonic=RMT, unit=DEGC, value=18.0, descr=Mud Sample Temperature),
#   HeaderItem(mnemonic=RANGE, unit=, value=PD 176, descr=Range),
#   HeaderItem(mnemonic=RMC, unit=OHMM, value=0.234, descr=Resistivity of Mud Ca...),
#   HeaderItem(mnemonic=RMF, unit=OHMM, value=0.1574, descr=Resistivity of Mud F...),
#   HeaderItem(mnemonic=RM, unit=OHMM, value=0.1637, descr=Resistivity of Mud Sa...),
#   HeaderItem(mnemonic=SECTION, unit=, value=45.20 Deg N, descr=Section),
#   HeaderItem(mnemonic=TIMC, unit=, value=18 01, descr=Time Circulation Stopped),
#   HeaderItem(mnemonic=TIML, unit=, value=1 35, descr=Time Logger At Bottom),
#   HeaderItem(mnemonic=TOWNSHIP, unit=, value=63.75 Deg W, descr=Township),
#   HeaderItem(mnemonic=WIT, unit=, value=Edwin MacDonald, descr=Witness's Name),
#   HeaderItem(mnemonic=APD, unit=M, value=4.5, descr=Above Permanent Datum),
#   HeaderItem(mnemonic=APIN, unit=, value=, descr=API Serial Number),
#   HeaderItem(mnemonic=BHT, unit=DEGC, value=42.0, descr=Bottom Hole Temperatur...),
#   HeaderItem(mnemonic=BLI, unit=M, value=1935.0, descr=Bottom Log Interval),
#   HeaderItem(mnemonic=BS, unit=MM, value=200.0, descr=Bit Size),
#   HeaderItem(mnemonic=CN, unit=, value=Elmworth Energy Corporation, descr=Comp...),
#   HeaderItem(mnemonic=COUN, unit=, value=Nova Scotia, descr=County or Rig Name),
#   HeaderItem(mnemonic=LDAT, unit=, value=10-Oct-2007, descr=Date as Month-Day-...),
#   HeaderItem(mnemonic=DCS, unit=, value=10-Oct-2007, descr=Date Circulation St...),
#   HeaderItem(mnemonic=DFL, unit=C3, value=7.5, descr=Drilling Fluid Loss),
#   HeaderItem(mnemonic=DLAB, unit=, value=11-Oct-2007, descr=Date Logger At Bottom),
#   HeaderItem(mnemonic=DMF, unit=, value=KELLY BUSHING, descr=Drilling Measured...),
#   HeaderItem(mnemonic=EDF, unit=M, value=94.5, descr=Elevation of Derrick Floor),
#   HeaderItem(mnemonic=EGL, unit=M, value=90.3, descr=Elevation of Ground Level),
#   HeaderItem(mnemonic=EKB, unit=M, value=94.8, descr=Elevation of Kelly Bushing),
#   HeaderItem(mnemonic=FD, unit=K/M3, value=1000.0, descr=Fluid Density),
#   HeaderItem(mnemonic=FL1, unit=, value=Long = 63* 45'24.460  W, descr=Field L...),
#   HeaderItem(mnemonic=FL2, unit=, value=, descr=Field Location Line 2),
#   HeaderItem(mnemonic=FN, unit=, value=Windsor Block, descr=Field Name),
#   HeaderItem(mnemonic=HID1, unit=, value=Litho-Density / Neutron Porosity, des...),
#   HeaderItem(mnemonic=HID2, unit=, value=, descr=Header Identifier Line 2),
#   HeaderItem(mnemonic=HIDE, unit=, value=Platform Express - Dual Density, desc...),
#   HeaderItem(mnemonic=LATI, unit=, value=, descr=Latitude),
#   HeaderItem(mnemonic=LMF, unit=, value=KELLY BUSHING, descr=Log Measured From),
#   HeaderItem(mnemonic=LONG, unit=, value=, descr=Longitude),
#   HeaderItem(mnemonic=MATR, unit=, value=SAND, descr=Rock Matrix for Neutron P...),
#   HeaderItem(mnemonic=MCSS, unit=, value=Mud Press, descr=Mud Cake Sample Source),
#   HeaderItem(mnemonic=MDEN, unit=K/M3, value=2650.0, descr=Matrix Density),
#   HeaderItem(mnemonic=MRT1, unit=DEGC, value=42.0, descr=Maximum Recorded Temp...),
#   HeaderItem(mnemonic=MRT2, unit=, value=, descr=Maximum Recorded Temperature 2),
#   HeaderItem(mnemonic=NMT, unit=, value=NOBARITE, descr=HILT Nuclear Mud Type),
#   HeaderItem(mnemonic=OS1, unit=, value=HRLA, descr=Other Services Line 1),
#   HeaderItem(mnemonic=OS2, unit=, value=ECS, descr=Other Services Line 2),
#   HeaderItem(mnemonic=OS3, unit=, value=FMI, descr=Other Services Line 3),
#   HeaderItem(mnemonic=OS4, unit=, value=DSI, descr=Other Services Line 4),
#   HeaderItem(mnemonic=OS5, unit=, value=, descr=Other Services Line 5),
#   HeaderItem(mnemonic=PDAT, unit=, value=GROUND LEVEL, descr=Permanent Datum),
#   HeaderItem(mnemonic=R1, unit=, value=Toolstring run as per toolsketch, descr...),
#   HeaderItem(mnemonic=R2, unit=, value=Primary matrix for logs is sandstone (2...),
#   HeaderItem(mnemonic=R3, unit=, value=HRLA run with 38.1 mm standoffs, descr=...),
#   HeaderItem(mnemonic=R4, unit=, value=All logs run from TD to Casing, descr=R...),
#   HeaderItem(mnemonic=R5, unit=, value=Pulled tight at 1913 m - closed and reo...),
#   HeaderItem(mnemonic=R6, unit=, value=GR and Neutron run from Casing to Surfa...),
#   HeaderItem(mnemonic=R7, unit=, value=Dual Litho-density log in X and Y axis,...),
#   HeaderItem(mnemonic=R8, unit=, value=-, descr=Remark Line 8),
#   HeaderItem(mnemonic=R9, unit=, value=-, descr=Remark Line 9),
#   HeaderItem(mnemonic=R10, unit=, value=-, descr=Remark Line 10),
#   HeaderItem(mnemonic=R11, unit=, value=-, descr=Remark Line 11),
#   HeaderItem(mnemonic=R12, unit=, value=-, descr=Remark Line 12),
#   HeaderItem(mnemonic=R13, unit=, value=-, descr=Remark Line 13),
#   HeaderItem(mnemonic=R14, unit=, value=-, descr=Remark Line 14),
#   HeaderItem(mnemonic=RMB, unit=OHMM, value=0.10187, descr=Resistivity of Mud ...),
#   HeaderItem(mnemonic=RMFB, unit=OHMM, value=0.09522, descr=Resistivity of Mud...),
#   HeaderItem(mnemonic=SON, unit=, value=11864196, descr=Service Order Number),
#   HeaderItem(mnemonic=TDD, unit=M, value=1935.0, descr=Total Depth - Driller),
#   HeaderItem(mnemonic=TDL, unit=M, value=1935.0, descr=Total Depth - Logger),
#   HeaderItem(mnemonic=TLI, unit=M, value=280.0, descr=Top Log Interval),
#   HeaderItem(mnemonic=UWID, unit=, value=, descr=Unique Well Identification Nu...),
#   HeaderItem(mnemonic=WN, unit=, value=Kennetcook #2, descr=Well Name),
#   HeaderItem(mnemonic=EPD, unit=M, value=90.300003, descr=Elevation of Permane...)],
#  'Other': ''}

# %%
l.curves
# Out:
# [CurveItem(mnemonic=DEPT, unit=m, value=, descr=DEPTH, original_mnemonic=DEPT, data.shape=(12718,)),
#  CurveItem(mnemonic=CALI, unit=in, value=, descr=Caliper, original_mnemonic=CALI, data.shape=(12718,)),
#  CurveItem(mnemonic=HCAL, unit=in, value=, descr=HRCC Cal. Caliper, original_mnemonic=HCAL, data.shape=(12718,)),
#  CurveItem(mnemonic=PEF, unit=, value=, descr=Photoelectric Factor, original_mnemonic=PEF, data.shape=(12718,)),
#  CurveItem(mnemonic=DT, unit=us/ft, value=, descr=DT, original_mnemonic=DT, data.shape=(12718,)),
#  CurveItem(mnemonic=DTS, unit=us/ft, value=, descr=DTS, original_mnemonic=DTS, data.shape=(12718,)),
#  CurveItem(mnemonic=DPHI_SAN, unit=m3/m3, value=, descr=Density Porosity (matrix Sandstone), original_mnemonic=DPHI_SAN, data.shape=(12718,)),
#  CurveItem(mnemonic=DPHI_LIM, unit=m3/m3, value=, descr=Density Porosity (matrix Limestone), original_mnemonic=DPHI_LIM, data.shape=(12718,)),
#  CurveItem(mnemonic=DPHI_DOL, unit=m3/m3, value=, descr=Density Porosity (matrix Dolomite), original_mnemonic=DPHI_DOL, data.shape=(12718,)),
#  CurveItem(mnemonic=NPHI_SAN, unit=m3/m3, value=, descr=Thermal Neutron Porosity (matrix Sandstone), original_mnemonic=NPHI_SAN, data.shape=(12718,)),
#  CurveItem(mnemonic=NPHI_LIM, unit=m3/m3, value=, descr=Thermal Neutron Porosity (matrix Limestone), original_mnemonic=NPHI_LIM, data.shape=(12718,)),
#  CurveItem(mnemonic=NPHI_DOL, unit=m3/m3, value=, descr=Thermal Neutron Porosity (matrix Dolomite), original_mnemonic=NPHI_DOL, data.shape=(12718,)),
#  CurveItem(mnemonic=RLA5, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 5, original_mnemonic=RLA5, data.shape=(12718,)),
#  CurveItem(mnemonic=RLA3, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 3, original_mnemonic=RLA3, data.shape=(12718,)),
#  CurveItem(mnemonic=RLA4, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 4, original_mnemonic=RLA4, data.shape=(12718,)),
#  CurveItem(mnemonic=RLA1, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 1, original_mnemonic=RLA1, data.shape=(12718,)),
#  CurveItem(mnemonic=RLA2, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 2, original_mnemonic=RLA2, data.shape=(12718,)),
#  CurveItem(mnemonic=RXOZ, unit=ohm.m, value=, descr=MCFL Standard Resolution Invaded Zone Resistivity, original_mnemonic=RXOZ, data.shape=(12718,)),
#  CurveItem(mnemonic=RXO_HRLT, unit=ohm.m, value=, descr=, original_mnemonic=RXO_HRLT, data.shape=(12718,)),
#  CurveItem(mnemonic=RT_HRLT, unit=ohm.m, value=, descr=HRLT Computed True Resistivity, original_mnemonic=RT_HRLT, data.shape=(12718,)),
#  CurveItem(mnemonic=RM_HRLT, unit=ohm.m, value=, descr=HRLT Mud Resistivity, original_mnemonic=RM_HRLT, data.shape=(12718,)),
#  CurveItem(mnemonic=DRHO, unit=g/cm3, value=, descr=HRDD Density Correction, original_mnemonic=DRHO, data.shape=(12718,)),
#  CurveItem(mnemonic=RHOB, unit=g/cm3, value=, descr=Bulk Density, original_mnemonic=RHOB, data.shape=(12718,)),
#  CurveItem(mnemonic=GR, unit=gAPI, value=, descr=Gamma-Ray, original_mnemonic=GR, data.shape=(12718,)),
#  CurveItem(mnemonic=SP, unit=mV, value=, descr=SP, original_mnemonic=SP, data.shape=(12718,))]

# %% [markdown]
# ## Look at the WELL section of the header

# %%
l.header['Well']
# Out:
# [HeaderItem(mnemonic=STRT, unit=M, value=1.0668, descr=START DEPTH),
#  HeaderItem(mnemonic=STOP, unit=M, value=1939.1376, descr=STOP DEPTH),
#  HeaderItem(mnemonic=STEP, unit=M, value=0.1524, descr=STEP),
#  HeaderItem(mnemonic=NULL, unit=, value=-999.25, descr=NULL VALUE),
#  HeaderItem(mnemonic=COMP, unit=, value=Elmworth Energy Corporation, descr=CO...),
#  HeaderItem(mnemonic=WELL, unit=, value=Kennetcook #2, descr=WELL),
#  HeaderItem(mnemonic=FLD, unit=, value=Windsor Block, descr=FIELD),
#  HeaderItem(mnemonic=LOC, unit=, value=Lat = 45* 12' 34.237" N, descr=LOCATION),
#  HeaderItem(mnemonic=PROV, unit=, value=Nova Scotia, descr=PROVINCE),
#  HeaderItem(mnemonic=UWI, unit=, value=Long = 63* 45'24.460  W, descr=UNIQUE ...),
#  HeaderItem(mnemonic=LIC, unit=, value=P-129, descr=LICENSE NUMBER),
#  HeaderItem(mnemonic=CTRY, unit=, value=CA, descr=COUNTRY (WWW code)),
#  HeaderItem(mnemonic=DATE, unit=, value=10-Oct-2007, descr=LOG DATE {DD-MMM-Y...),
#  HeaderItem(mnemonic=SRVC, unit=, value=Schlumberger, descr=SERVICE COMPANY),
#  HeaderItem(mnemonic=LATI, unit=DEG, value=, descr=LATITUDE),
#  HeaderItem(mnemonic=LONG, unit=DEG, value=, descr=LONGITUDE),
#  HeaderItem(mnemonic=GDAT, unit=, value=, descr=GeoDetic Datum),
#  HeaderItem(mnemonic=SECT, unit=, value=45.20 Deg N, descr=Section),
#  HeaderItem(mnemonic=RANG, unit=, value=PD 176, descr=Range),
#  HeaderItem(mnemonic=TOWN, unit=, value=63.75 Deg W, descr=Township)]

# %% [markdown]
# ## Look at the curve data

# %% [markdown]
# The curves are all present one big NumPy array:

# %%
l.data
# Out:
# array([[1.06680000e+00, 2.44381547e+00, 4.39128494e+00, ...,
#         2.39014983e+00, 4.66986504e+01, 1.20125000e+02],
#        [1.21920000e+00, 2.44381547e+00, 4.39128494e+00, ...,
#         2.39014983e+00, 4.66986504e+01, 1.20125000e+02],
#        [1.37160000e+00, 2.44381547e+00, 4.39128494e+00, ...,
#         2.39014983e+00, 4.66986504e+01, 1.20125000e+02],
#        ...,
#        [1.93883280e+03, 2.42026806e+00,            nan, ...,
#                    nan, 9.22462235e+01, 7.30000000e+01],
#        [1.93898520e+03, 2.42026806e+00,            nan, ...,
#                    nan, 9.22462235e+01, 7.39375000e+01],
#        [1.93913760e+03, 2.42026806e+00,            nan, ...,
#                    nan, 9.22462235e+01, 7.42500000e+01]])

# %%
l.curves
# Out:
# [CurveItem(mnemonic=DEPT, unit=m, value=, descr=DEPTH, original_mnemonic=DEPT, data.shape=(12718,)),
#  CurveItem(mnemonic=CALI, unit=in, value=, descr=Caliper, original_mnemonic=CALI, data.shape=(12718,)),
#  CurveItem(mnemonic=HCAL, unit=in, value=, descr=HRCC Cal. Caliper, original_mnemonic=HCAL, data.shape=(12718,)),
#  CurveItem(mnemonic=PEF, unit=, value=, descr=Photoelectric Factor, original_mnemonic=PEF, data.shape=(12718,)),
#  CurveItem(mnemonic=DT, unit=us/ft, value=, descr=DT, original_mnemonic=DT, data.shape=(12718,)),
#  CurveItem(mnemonic=DTS, unit=us/ft, value=, descr=DTS, original_mnemonic=DTS, data.shape=(12718,)),
#  CurveItem(mnemonic=DPHI_SAN, unit=m3/m3, value=, descr=Density Porosity (matrix Sandstone), original_mnemonic=DPHI_SAN, data.shape=(12718,)),
#  CurveItem(mnemonic=DPHI_LIM, unit=m3/m3, value=, descr=Density Porosity (matrix Limestone), original_mnemonic=DPHI_LIM, data.shape=(12718,)),
#  CurveItem(mnemonic=DPHI_DOL, unit=m3/m3, value=, descr=Density Porosity (matrix Dolomite), original_mnemonic=DPHI_DOL, data.shape=(12718,)),
#  CurveItem(mnemonic=NPHI_SAN, unit=m3/m3, value=, descr=Thermal Neutron Porosity (matrix Sandstone), original_mnemonic=NPHI_SAN, data.shape=(12718,)),
#  CurveItem(mnemonic=NPHI_LIM, unit=m3/m3, value=, descr=Thermal Neutron Porosity (matrix Limestone), original_mnemonic=NPHI_LIM, data.shape=(12718,)),
#  CurveItem(mnemonic=NPHI_DOL, unit=m3/m3, value=, descr=Thermal Neutron Porosity (matrix Dolomite), original_mnemonic=NPHI_DOL, data.shape=(12718,)),
#  CurveItem(mnemonic=RLA5, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 5, original_mnemonic=RLA5, data.shape=(12718,)),
#  CurveItem(mnemonic=RLA3, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 3, original_mnemonic=RLA3, data.shape=(12718,)),
#  CurveItem(mnemonic=RLA4, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 4, original_mnemonic=RLA4, data.shape=(12718,)),
#  CurveItem(mnemonic=RLA1, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 1, original_mnemonic=RLA1, data.shape=(12718,)),
#  CurveItem(mnemonic=RLA2, unit=ohm.m, value=, descr=HRLT Borehole Corrected Resistivity 2, original_mnemonic=RLA2, data.shape=(12718,)),
#  CurveItem(mnemonic=RXOZ, unit=ohm.m, value=, descr=MCFL Standard Resolution Invaded Zone Resistivity, original_mnemonic=RXOZ, data.shape=(12718,)),
#  CurveItem(mnemonic=RXO_HRLT, unit=ohm.m, value=, descr=, original_mnemonic=RXO_HRLT, data.shape=(12718,)),
#  CurveItem(mnemonic=RT_HRLT, unit=ohm.m, value=, descr=HRLT Computed True Resistivity, original_mnemonic=RT_HRLT, data.shape=(12718,)),
#  CurveItem(mnemonic=RM_HRLT, unit=ohm.m, value=, descr=HRLT Mud Resistivity, original_mnemonic=RM_HRLT, data.shape=(12718,)),
#  CurveItem(mnemonic=DRHO, unit=g/cm3, value=, descr=HRDD Density Correction, original_mnemonic=DRHO, data.shape=(12718,)),
#  CurveItem(mnemonic=RHOB, unit=g/cm3, value=, descr=Bulk Density, original_mnemonic=RHOB, data.shape=(12718,)),
#  CurveItem(mnemonic=GR, unit=gAPI, value=, descr=Gamma-Ray, original_mnemonic=GR, data.shape=(12718,)),
#  CurveItem(mnemonic=SP, unit=mV, value=, descr=SP, original_mnemonic=SP, data.shape=(12718,))]

# %% [markdown]
# Or we can go after a single curve object:

# %%
l.curves.GR.data
# Out:
# array([46.69865036, 46.69865036, 46.69865036, ..., 92.24622345,
#        92.24622345, 92.24622345])

# %% [markdown]
# And there's a shortcut to its data:

# %%
l['GR']
# Out:
# array([46.69865036, 46.69865036, 46.69865036, ..., 92.24622345,
#        92.24622345, 92.24622345])

# %% [markdown]
# ...so it's easy to make a plot against depth:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(15,3))
plt.plot(l['DEPT'], l['GR'])
plt.show()

# %% [markdown]
# ## Inspect the curves as a `pandas` dataframe

# %%
l.df().head()
# Out:
#             CALI      HCAL     PEF  DT  DTS  DPHI_SAN  DPHI_LIM  DPHI_DOL  \
# DEPT
# 1.0668  2.443815  4.391285  3.5864 NaN  NaN   0.15748   0.19844    0.2591
# 1.2192  2.443815  4.391285  3.5864 NaN  NaN   0.15748   0.19844    0.2591
# 1.3716  2.443815  4.391285  3.5864 NaN  NaN   0.15748   0.19844    0.2591
# 1.5240  2.443815  4.391285  3.5864 NaN  NaN   0.15748   0.19844    0.2591
# 1.6764  2.443815  4.391285  3.5864 NaN  NaN   0.15748   0.19844    0.2591
#
#         NPHI_SAN  NPHI_LIM   ...       RLA1     RLA2     RXOZ  RXO_HRLT  \
# DEPT                         ...
# 1.0668    0.4651   0.33647   ...     0.0321  0.02794  0.05761   0.02558
# 1.2192    0.4651   0.33647   ...     0.0321  0.02794  0.05761   0.02558
# 1.3716    0.4651   0.33647   ...     0.0321  0.02794  0.05761   0.02558
# 1.5240    0.4651   0.33647   ...     0.0321  0.02794  0.05761   0.02558
# 1.6764    0.4651   0.33647   ...     0.0321  0.02794  0.05761   0.02558
#
#         RT_HRLT  RM_HRLT      DRHO     RHOB        GR       SP
# DEPT
# 1.0668  0.02558  0.05501  0.194233  2.39015  46.69865  120.125
# 1.2192  0.02558  0.05501  0.194233  2.39015  46.69865  120.125
# 1.3716  0.02558  0.05501  0.194233  2.39015  46.69865  120.125
# 1.5240  0.02558  0.05501  0.194233  2.39015  46.69865  120.125
# 1.6764  0.02558  0.05501  0.194233  2.39015  46.69865  120.125
#
# [5 rows x 24 columns]

# %%
plt.plot(l.df().GR)

# %% [markdown]
# ## Load the LAS file with `welly`
#
# `welly` uses `lasio` to load the file. Then it adds some handy things:
#
# - Richer `curve` objects (subclassed NumPy arrays), with smoothing, resampling, plotting, and more.
# - Curve alias lists.
# - Curve quality checking.
# - Remapping and transforming fields during LAS load.
# - A `project` object for managing several wells at once.
# - A `well.location` property, with a CRS and directional survey.
# - Jupyter Notebook friendly object representations.

# %%
from welly import Well

w = Well.from_las('../data/P-129.LAS')

# %% [markdown]
# `welly` Wells know how to display some basics:

# %%
w
# Out:
# Well(uwi: 'Long = 63* 45'24.460  W', 24 curves: ['CALI', 'HCAL', 'PEF', 'DT', 'DTS', 'DPHI_SAN', 'DPHI_LIM', 'DPHI_DOL', 'NPHI_SAN', 'NPHI_LIM', 'NPHI_DOL', 'RLA5', 'RLA3', 'RLA4', 'RLA1', 'RLA2', 'RXOZ', 'RXO_HRLT', 'RT_HRLT', 'RM_HRLT', 'DRHO', 'RHOB', 'GR', 'SP'])

# %% [markdown]
# And the `Well` object also has `lasio`'s access to a pandas DataFrame:

# %%
w.df().head()
# Out:
#             CALI      HCAL     PEF  DT  DTS  DPHI_SAN  DPHI_LIM  DPHI_DOL  \
# Depth
# 1.0668  2.443815  4.391285  3.5864 NaN  NaN   0.15748   0.19844    0.2591
# 1.2192  2.443815  4.391285  3.5864 NaN  NaN   0.15748   0.19844    0.2591
# 1.3716  2.443815  4.391285  3.5864 NaN  NaN   0.15748   0.19844    0.2591
# 1.5240  2.443815  4.391285  3.5864 NaN  NaN   0.15748   0.19844    0.2591
# 1.6764  2.443815  4.391285  3.5864 NaN  NaN   0.15748   0.19844    0.2591
#
#         NPHI_SAN  NPHI_LIM   ...       RLA1     RLA2     RXOZ  RXO_HRLT  \
# Depth                        ...
# 1.0668    0.4651   0.33647   ...     0.0321  0.02794  0.05761   0.02558
# 1.2192    0.4651   0.33647   ...     0.0321  0.02794  0.05761   0.02558
# 1.3716    0.4651   0.33647   ...     0.0321  0.02794  0.05761   0.02558
# 1.5240    0.4651   0.33647   ...     0.0321  0.02794  0.05761   0.02558
# 1.6764    0.4651   0.33647   ...     0.0321  0.02794  0.05761   0.02558
#
#         RT_HRLT  RM_HRLT      DRHO     RHOB        GR       SP
# Depth
# 1.0668  0.02558  0.05501  0.194233  2.39015  46.69865  120.125
# 1.2192  0.02558  0.05501  0.194233  2.39015  46.69865  120.125
# 1.3716  0.02558  0.05501  0.194233  2.39015  46.69865  120.125
# 1.5240  0.02558  0.05501  0.194233  2.39015  46.69865  120.125
# 1.6764  0.02558  0.05501  0.194233  2.39015  46.69865  120.125
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Look at `welly`'s Curve object
#
# The `data` attribute is just a dictionary:

# %%
w.data
# Out:
# {'CALI': Curve([2.44381547, 2.44381547, 2.44381547, ..., 2.42026806, 2.42026806,
#         2.42026806]),
#  'HCAL': Curve([4.39128494, 4.39128494, 4.39128494, ...,        nan,        nan,
#                nan]),
#  'PEF': Curve([3.58640003, 3.58640003, 3.58640003, ..., 2.23697996, 2.23697996,
#         2.23697996]),
#  'DT': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'DTS': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'DPHI_SAN': Curve([0.15748   , 0.15748   , 0.15748   , ..., 0.54641998, 0.54641998,
#         0.54641998]),
#  'DPHI_LIM': Curve([1.98440000e-01, 1.98440000e-01, 1.98440000e-01, ...,
#         5.85941528e+02, 5.85941528e+02, 5.85941528e+02]),
#  'DPHI_DOL': Curve([2.5909999e-01, 2.5909999e-01, 2.5909999e-01, ..., 5.4167572e+02,
#         5.4167572e+02, 5.4167572e+02]),
#  'NPHI_SAN': Curve([0.46509999, 0.46509999, 0.46509999, ..., 0.12834001, 0.12834001,
#         0.12834001]),
#  'NPHI_LIM': Curve([0.33647001, 0.33647001, 0.33647001, ..., 0.08417   , 0.08417   ,
#         0.08417   ]),
#  'NPHI_DOL': Curve([0.30186, 0.30186, 0.30186, ..., 0.05256, 0.05256, 0.05256]),
#  'RLA5': Curve([2.55800001e-02, 2.55800001e-02, 2.55800001e-02, ...,
#         7.82533508e+02, 7.82533508e+02, 7.82533508e+02]),
#  'RLA3': Curve([2.67500002e-02, 2.67500002e-02, 2.67500002e-02, ...,
#         7.13433655e+02, 7.13433655e+02, 7.13433655e+02]),
#  'RLA4': Curve([2.56200004e-02, 2.56200004e-02, 2.56200004e-02, ...,
#         7.52805481e+02, 7.52805481e+02, 7.52805481e+02]),
#  'RLA1': Curve([3.20999995e-02, 3.20999995e-02, 3.20999995e-02, ...,
#         2.74026489e+02, 2.74026489e+02, 2.74026489e+02]),
#  'RLA2': Curve([2.79399995e-02, 2.79399995e-02, 2.79399995e-02, ...,
#         6.63104065e+02, 6.63104065e+02, 6.63104065e+02]),
#  'RXOZ': Curve([0.05761   , 0.05761   , 0.05761   , ..., 7.09686995, 7.03910017,
#         7.00194979]),
#  'RXO_HRLT': Curve([0.02558, 0.02558, 0.02558, ...,     nan,     nan,     nan]),
#  'RT_HRLT': Curve([0.02558   , 0.02558   , 0.02558   , ..., 7.38065004, 7.32116985,
#         7.1535902 ]),
#  'RM_HRLT': Curve([0.05501, 0.05501, 0.05501, ..., 0.02729, 0.02729, 0.02729]),
#  'DRHO': Curve([0.19423294, 0.19423294, 0.19423294, ..., 0.06139515, 0.06139515,
#         0.06139515]),
#  'RHOB': Curve([2.39014983, 2.39014983, 2.39014983, ...,        nan,        nan,
#                nan]),
#  'GR': Curve([46.69865036, 46.69865036, 46.69865036, ..., 92.24622345,
#         92.24622345, 92.24622345]),
#  'SP': Curve([120.125 , 120.125 , 120.125 , ...,  73.    ,  73.9375,  74.25  ])}

# %% [markdown]
# Like the `Well`, a `Curve` object can report a bit about itself:

# %%
gr = w.data['GR']
gr
# Out:
# Curve([46.69865036, 46.69865036, 46.69865036, ..., 92.24622345,
#        92.24622345, 92.24622345])

# %% [markdown]
# To get at the depth in a `lasio` object, you have to find the `DEPT` curve:

# %%
w.las.curves.DEPT
# Out:
# CurveItem(mnemonic=DEPT, unit=m, value=, descr=DEPTH, original_mnemonic=DEPT, data.shape=(12718,))

# %% [markdown]
# One important thing about `Curve` objects is that each one knows its own depths — they are stored as a property called `basis`. (It's not actually stored, but computed on demand from the start depth, the sample interval (which must be constant for the whole curve) and the number of samples in the object.)

# %%
gr.basis
# Out:
# array([1.0668000e+00, 1.2192000e+00, 1.3716000e+00, ..., 1.9388328e+03,
#        1.9389852e+03, 1.9391376e+03])

# %%
gr.plot()

# %% [markdown]
# ## Plot part of a curve
#
# We'll grab the interval from 300 m to 1000 m and plot it.

# %%
gr.to_basis(start=300, stop=1000).plot()  # Line 8.

# %%
gr.to_basis(start=500, stop=510, step=0.1).plot(color='r')

# %% [markdown]
# ## Curve quality
#
# We can run qualaity tests on wells or on projects.

# %%
from IPython.display import HTML
import welly.quality as qc

tests = {
    'each': [qc.no_gaps, qc.no_monotonic],
    'GR': [qc.all_positive]
}

results = w.qc_table_html(tests=tests)

HTML(results)
# Out:
# <table><tr><th>Curve</th><th>Passed</th><th>Score</th><th>no_gaps</th><th>all_positive</th><th>no_monotonic</th></tr><tr><th>CALI</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>HCAL</th><td>0 / 2</td><td>0.000</td><td style="background-color:#FFCCCC;">False</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>PEF</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>DT</th><td>1 / 2</td><td>0.500</td><td style="background-color:#FFCCCC;">False</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#CCEECC;">True</td></tr><tr><th>DTS</th><td>1 / 2</td><td>0.500</td><td style="background-color:#FFCCCC;">False</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#CCEECC;">True</td></tr><tr><th>DPHI_SAN</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>DPHI_LIM</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>DPHI_DOL</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>NPHI_SAN</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>NPHI_LIM</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>NPHI_DOL</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>RLA5</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>RLA3</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>RLA4</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>RLA1</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>RLA2</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>RXOZ</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>RXO_HRLT</th><td>0 / 2</td><td>0.000</td><td style="background-color:#FFCCCC;">False</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>RT_HRLT</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>RM_HRLT</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td><td style="background-color:#EEEEEE;"></td><td style="background-color:#FFCCCC;">False</td></tr><tr><th>DRHO</th><td>1 / 2</td><td>0.500</td><td style="background-color:#CCEECC;">True</td ...

# %% [markdown]
# ## Smooth a curve
#
# Curve objects are, fundamentally, NumPy arrays. But they have some extra tricks. We've already seen `Curve.plot()`.
#
# Using the `Curve.smooth()` method, we can easily smooth a curve, eg by 15 m (passing `samples=True` would smooth by 15 samples):

# %%
sm = gr.smooth(window_length=15, samples=False)

fig, ax = plt.subplots(figsize=(2,10))
ax = gr.plot(ax=ax)
ax = sm.plot(ax=ax, lw=2)

# %% [markdown]
# We can save this as a new LAS file:

# %%
x = Well(params={'name': w.header.name})
x.header = w.header
x.location = w.location

# %%
x.data['GR'] = w.data['GR']

x.data['GR_smooth'] = sm

x.data
# Out:
# {'GR': Curve([46.69865036, 46.69865036, 46.69865036, ..., 92.24622345,
#         92.24622345, 92.24622345]),
#  'GR_smooth': Curve([ 46.69865036,  46.69865036,  46.69865036, ..., 112.05710602,
#         111.60685869, 111.15661136])}

# %%
x.to_las('../data/x.las')

# %% [markdown]
# ## Export a set of curves as a matrix

# %% [markdown]
# `welly` lets you specify which curves you want (optionally using aliases like GR1, GRC, NGC, etc for GR), resample the data, or specify a start and stop depth. This method is also wrapped by `Project.data_as_matrix()` which is nice because it ensures that all the wells are exported at the same sample interval.
#
# Here are the curves in this well:

# %%
w.data.keys()
# Out:
# dict_keys(['CALI', 'HCAL', 'PEF', 'DT', 'DTS', 'DPHI_SAN', 'DPHI_LIM', 'DPHI_DOL', 'NPHI_SAN', 'NPHI_LIM', 'NPHI_DOL', 'RLA5', 'RLA3', 'RLA4', 'RLA1', 'RLA2', 'RXOZ', 'RXO_HRLT', 'RT_HRLT', 'RM_HRLT', 'DRHO', 'RHOB', 'GR', 'SP'])

# %% [markdown]
# Let's say we only want to export a few curves for our machine learning project:

# %%
keys = ['CALI', 'DT', 'DTS', 'RHOB', 'SP']

# %%
w.plot(tracks=['TVD']+keys)

# %%
X, basis = w.data_as_matrix(keys=keys, start=275, stop=1850, step=0.5, return_basis=True)

# %%
w.data['CALI'].shape
# Out:
# (12718,)

# %% [markdown]
# So CALI had 12,718 points in it... since we downsampled to 0.5 m and removed the top and tail, we should have substantially fewer points:

# %%
X.shape
# Out:
# (3151, 5)

# %%
plt.figure(figsize=(15,3))
plt.plot(X.T[0])
plt.show()

# %% [markdown]
# ## The `Project` class
#
# We can also load multiple wells into a Welly `Project`:

# %%
from welly import Project

p = Project.from_las('../data/*.las')
# Out:
# 5it [00:06,  1.04s/it]Header section Parameter regexp=~P was not found.
# 6it [00:08,  1.33s/it]

# %%
p
# Out:
# Project(6 wells: 4004614505993500, , , Long = 63* 45'24.460  W, 303N764340060300, )

# %% [markdown]
# Projects are really just lists of wells:

# %%
p[4]
# Out:
# Well(uwi: '303N764340060300', 22 curves: ['BS', 'CALI', 'CHR1', 'CHR2', 'CHRP', 'CHRS', 'DRHO', 'DT1R', 'DT2', 'DT2R', 'DT4P', 'DT4S', 'GR', 'HD1', 'HD2', 'HD3', 'NPOR', 'PEF', 'RHOB', 'SPR1', 'TENS', 'VPVS'])

# %% [markdown]
# ## BONUS: fix the lat, lon
#
# **Warning:** This is pretty gross. But you're going to need it sooner or later...
#
# Did you notice that the location of the well did not get loaded properly?

# %%
w.uwi
# Out:
# "Long = 63* 45'24.460  W"

# %%
w.location
# Out:
# Location({'td': 1935.0, 'crs': CRS({}), 'location': 'Lat = 45* 12\' 34.237" N', 'country': 'CA', 'province': 'Nova Scotia', 'section': '45.20 Deg N', 'range': 'PD 176', 'township': '63.75 Deg W', 'kb': 94.8, 'gl': 90.3, 'tdd': 1935.0, 'tdl': 1935.0, 'deviation': None, 'position': None})

# %% [markdown]
# Let's look at some of the header:
#
#     # LAS format log file from PETREL
#     # Project units are specified as depth units
#     #==================================================================
#     ~Version information
#     VERS.   2.0:
#     WRAP.   YES:
#     #==================================================================
#     ~WELL INFORMATION
#     #MNEM.UNIT      DATA             DESCRIPTION
#     #---- ------ --------------   -----------------------------
#     STRT .M      1.0668          :START DEPTH
#     STOP .M      1939.13760      :STOP DEPTH
#     STEP .M       0.15240        :STEP
#     NULL .          -999.25      :NULL VALUE
#     COMP .        Elmworth Energy Corporation              :COMPANY
#     WELL .        Kennetcook #2                            :WELL
#     FLD  .        Windsor Block                            :FIELD
#     LOC  .        Lat = 45* 12' 34.237" N                  :LOCATION
#     PROV .        Nova Scotia                              :PROVINCE
#       UWI.        Long = 63* 45'24.460  W                  :UNIQUE WELL ID
#     LIC  .        P-129                                    :LICENSE NUMBER
#     CTRY .        CA                                       :COUNTRY (WWW code)
#      DATE.        10-Oct-2007                              :LOG DATE {DD-MMM-YYYY}
#     SRVC .        Schlumberger                             :SERVICE COMPANY
#     LATI .DEG                                              :LATITUDE
#     LONG .DEG                                              :LONGITUDE
#     GDAT .                                                 :GeoDetic Datum
#     SECT .        45.20 Deg N                              :Section
#     RANG .        PD 176                                   :Range
#     TOWN .        63.75 Deg W                              :Township
#
# Look at **LOC** and **UWI**. There are two problems:
#
# 1. These items are in the wrong place. (Notice **LATI** and **LONG** are empty.)
# 2. The items are malformed, with lots of extraneous characters.
#
# We can fix this in two steps:
#
# 1. Remap the header items to fix the first problem.
# 2. Parse the items to fix the second one.
#
# We'll define these in reverse because the remapping uses the transforming function.

# %%
import re
import welly

def transform_ll(text):
    """
    Parses malformed lat and lon so they load properly.
    """
    def callback(match):
        d = match.group(1).strip()
        m = match.group(2).strip()
        s = match.group(3).strip()
        c = match.group(4).strip()
        if c.lower() in ('w', 's') and d[0] != '-':
            d = '-' + d
        return ' '.join([d, m, s])
    pattern = re.compile(r""".+?([-0-9]+?).? ?([0-9]+?).? ?([\.0-9]+?).? +?([NESW])""", re.I)
    text = pattern.sub(callback, text)
    return welly.utils.dms2dd([float(i) for i in text.split()])

# %% [markdown]
# Make sure that works!

# %%
print(transform_ll("""Lat = 45* 12' 34.237" N"""))
# Out:
# 45.20951027777778

# %% [markdown]
# It does!
#
# Now we can define two dictionaries:
#
# - `remap` tells welly what to use for certain fields when loading the well. The first item says, "Use whatever is in the LOC parameter for the LATI parameter"... or "Get LATI from LOC". The last item says, "Don't load the parameter TOWN from this file" and it will thus be ignored.
#
# - `funcs` tells welly what functions to run on a field as it is loaded. Note that if we remap a field, you specify the field you are mapping TO (that is, the target field name) as the key. The first item in the `funcs` dict, below, tells welly to pass the parameter through the function `transform_ll` during loading.

# %%
remap = {
    'LATI': 'LOC',  # Use LOC for the parameter LATI.
    'LONG': 'UWI',  # Use UWI for the parameter LONG.
    'LOC':  None,   # Use nothing for the parameter SECT.
    'SECT': None,   # Use nothing for the parameter SECT.
    'RANG': None,   # Use nothing for the parameter RANG.
    'TOWN': None,   # Use nothing for the parameter TOWN.
}

funcs = {
    'LATI': transform_ll,  # Pass LATI through this function before loading.
    'LONG': transform_ll,  # Pass LONG through it too.
    'UWI': lambda x: "No UWI, fix this!"
}

# %% [markdown]
# Now we can load the file again, this time with the `remap` and `funcs`:

# %%
w = Well.from_las('../data/P-129.LAS', remap=remap, funcs=funcs)

# %% [markdown]
# Let's see if it fixed the problem:

# %%
w.location.latitude, w.location.longitude
# Out:
# (45.20951027777778, -62.243205555555555)

# %%
w.location
# Out:
# Location({'td': None, 'crs': CRS({}), 'country': 'CA', 'province': 'Nova Scotia', 'latitude': 45.20951027777778, 'longitude': -62.243205555555555, 'deviation': None, 'position': None})

# %%
w.uwi
# Out:
# 'No UWI, fix this!'

# %% [markdown]
# Yes!
#
# Let's just hope the mess is the same mess in every well. (LOL, no-one's that lucky.)

# %% [markdown]
# <hr>
#
# **&copy; 2017 [agilescientific.com](https://www.agilescientific.com/) and licensed [CC-BY 4.0](https://creativecommons.org/licenses/by/4.0/)**
